# %%
import time

def wait(duration):
    time.sleep(duration)


def character_backstory():
    username = input("Type in your username please.") #This will be gotten from the username function.
    wait(2)
    print("There was once a great person who fought for the freedom of their village!, their name?")
    wait(2)
    print(username)
    wait(2)
    print(username, "was a war veteran who fought for his country...")
    wait(4)
    print("After facing the final boss for the first time in order to defend his village...")
    wait(6)
    print("To protect his village he had to fight many strong foes...")
    wait(4)
    print(username, "fails and is presumed dead, his village enslaved...")
    wait(4)
    print(username, "wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.")
    wait(4)
    #Call next function(class_selection)



character_backstory()
# Out:
# Type in your username please.Taco
# There was once a great person who fought for the freedom of their village!, their name?
# Taco
# Taco was a war veteran who fought for his country...
# After facing the final boss for the first time in order to defend his village...
# To protect his village he had to fight many strong foes...
# Taco fails and is presumed dead, his village enslaved...
# Taco wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.

# %%
#def character_background (): 
    filename = 'character_backround.txt'
    with open(filename, 'r') as background:
        background_text = background.read()
        print(username, background_text)

character_background()
# Out:
# Tacobell is a war veteran, fighting for his country...
# He has a unique skill set and varying abilities...
# To protect his village he must fight many strong foes...
# After facing the final boss for the first time in order to defend his village...
# He fails and is presumed dead, his village enslaved...
# He wakes up with no memory of who he was and soon realizes that, surprisingly, he has skills from muscle memory clearly embedded in him from years of experience.

# %%
#Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
#Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
#Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
#Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!

def sleep_unlockskills_knight (): #character dream function
    sleep_count = 0 #keep running count of how many times they've sleep, note: user-interface will only show option to sleep after facing final boss. 
    while sleep_count < 4 : #While count is less than 3, continue
        sleep_count + 1
        if sleep_count == 0 :
            slash_knight_permission ='Granted' #Sets permission granted for this skill, allows it to be seen in user_interface. Use if statements.
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 1 :
            lunge_knight_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 2 :
            ironguardian_knight_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 3: 
            pivotdash_knight_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 4 :
            true_edge_knight_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        else :
            print("You can no longer sleep.") 
            print("error, check sleep knight function.")


def sleep_unlockskills_archer (user_option): #character dream function
    sleep_count = -1 #keep running count out of the function note: user-interface will only show option to sleep after facing final boss. 
    while sleep_count <= 4 : #While count is less than 3, continue
        sleep_count + 1
        if sleep_count == 0 :
            arrow_archer_permission = 'Granted' #Sets permission granted for this skill, allows it to be seen in user_interface. Use if statements.
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 1 :
            precisionhit_archer_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 2 :
            focusbreath_archer_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 3: 
            acidarrow_archer_permission = 'Granted'
            print("You had a nice rest")
            #Call User_interface
            break
        elif sleep_count == 4 :
            stormarrow_archer_permission = 'Granted'
            print("You had a nice rest")
            break
            #Call User_interface
        else :
            print("You can no longer sleep.")
            print("error, check sleep archer function.")

            
def sleep_unlockskills_wizard (user_option): #character dream function
    sleep_count = 0 #keep running count of how many times they've sleep, note: user-interface will only show option to sleep after facing final boss. 
    while sleep_count < 4 : #While count is less than 3, continue
        sleep_count + 1
        if sleep_count == 0 :
            fireblast_wizard_permission = 'Granted' #Sets permission granted for this skill, allows it to be seen in user_interface. Use if statements
            print("You had a nice rest")
            break
            #Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
        elif sleep_count == 1 :
            lightningstrike_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 2 :
            heal_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 3: 
            element_wave_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 4 :
            eruption_seal_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        else :
            print("You can no longer sleep.")
            print("error, check sleep wizard function.")

def sleep_restore_knightpp():
    slash_pp = 15
    lunge_pp = 10
    ironguardian_pp = 2
    pivotdash_pp = 10
    true_edge_pp = 1
    return slash_pp, lunge_pp, ironguardian_pp, pivotdash_pp, true_edge_pp
    
def sleep_restore_archerpp():
    arrow_pp = 15
    precisionhit_pp = 10
    focusbreath_pp = 2
    acidarrow_pp = 10
    stormarrow_pp = 1
    return arrow_pp, precisionhit_pp, focus_breath_pp, acidarrow_pp, stormarrow_pp
def sleep_restore_wizardpp():
    fireblast_pp = 10
    lightningstrike_pp = 10
    heal_pp = 2
    element_wave_pp = 10
    eruption_seal_wizard = 1
    return fireblast_pp, lightningstrike_pp, heal_pp, element_wave_pp, eruption_seal_wizard


#TownOptions
if user_option == 'sleep': #This will be used in the user interface, if the user types sleep, 
    if user_stats['CharacterType'] == 'Knight':
        sleep_unlockskills_knight()
        sleep_restore_knightpp()
    elif user_stats['CharacterType'] == 'Archer':
        sleep_unlockskills_archer()
        sleep_restore_archerpp()
    elif user_stats['CharacterType'] == 'Wizard':
        sleep_unlockskills_wizard()
        sleep_restore_wizardpp()
    else:
        print("Error, check sleep test.")
else :
    print("Code into overall for user_interface.")
    #Rerun user_interface
# Out:
# Test.nuby
# Code into overall for user_interface.
