# %%
import random
import time

def wait(duration):
    time.sleep(duration)

#Asks whether they would like to skip and go to jounrey start or go through then go to journey start.
def character_backstory(username):
    user_skip = input("Would you like to skip the backstory? 'Yes' or 'No'.")
    user_skipl = user_skip.lower()
    if user_skipl == 'yes':
        journey_start()
    elif user_skipl == 'no' :
        wait(3)
        print("There was once a great person who fought for the freedom of their village, his name is ")
        wait(3)
        print(username)
        wait(2)
        print(username, "was a war veteran who fought for his country...")
        wait(3)
        print("To protect his village he had to fight many monsters...")
        wait(3)
        print("In order to defend his vilage", username, "faced the monster boss, kragula...")
        wait(4)
        print(username, "fails to win the fight and is presumed dead, his village, enslaved...")
        wait(3)
        print(username, "wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.")
        wait(4)
        journey_start()
    else :
        print("You must type 'Yes' or 'No'.")
    

def display_user_stats(user_stats):
    for keys, values in user_stats.items() :
        print(keys + ":", values)
#Displaus user stats, takes them from dictionary. 
#Note: Need to reconfigure user_stats into a global variable


namecheck = [] #Creates empty list
filename='Random_Name_Data.txt' #Pulls up file with all the random names
with open (filename,'r') as namelist: 
    for name in namelist.readlines():
        namecheck.append(name) #Adds nall names in the random name file to namecheck
while True:
    user_input = input("Please enter a username, or type 'random' to receive a random name: ")
    if user_input == 'random' :
        username = random.choice(namecheck)
        print("Your randomly generated username is %s." % (username))
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_inputl = confirm_input.lower()
        if confirm_inputl == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else : 
            print("Please try again. Restarting...")
            wait(2)
    else:
        username = user_input
        print("Your username is now:", username)
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_inputl = confirm_input.lower()
        if confirm_inputl == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else :
            print("Please try again. Restarting...")
            wait(2)
    
knight_stats = {'CharacterType':'Knight','health':75,'armor':70,'speed':35,'attack':20}
archer_stats = {'CharacterType': 'Archer','health':70,'armor':50,'speed':55,'attack':35}
wizard_stats = {'CharacterType':'Wizard','health':65,'armor':50,'speed':25,'attck':45}
goblin_stats = {'CharacterType':'Goblin','health':45,'armor':10,'speed':35,'attack':25}
darkelf_stats = {'CharacterType':'Darkelves','health':55,'armor':25,'speed':40,'attack':35}
vampire_stats={'CharacterType':'Vampire','health':70,'armor':30,'speed':40,'attack':35}
werewolf_stats={'CharacterType':'Werewolf','health':80,'armor':55,'speed':50,'attack':55}
dragon_stats={'CharacterType':'Dragon','health':100,'armor':100,'speed':100,'attack':100}
user_stats= {}
user_inventory = {}
class_variable = ''
sleep_count = 0

def journey_start():
    print("Welcome,", username + '.')
    
def class_choice(choice):
    if choice =='sword':
        class_variable = 'knight'
        user_stats = knight_stats
        print("Congratulations, you are now a knight!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    elif choice=='bow':
        class_variable = 'archer'
        user_stats = archer_stats
        print("Congratulations, you are now an archer!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    elif choice=='staff':
        class_variable = 'wizard'
        user_stats = wizard_stats
        print("Congratulations, you are now a wizard!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    else :
        print("Restarting journey...")
        journey_start()

journey_confirmation=input("Would you like to start your journey? Please enter 'yes' or 'no' to confirm.")
journey_confirmation = journey_confirmation.lower()
if journey_confirmation=="yes":
    print("\n\nYou wake up in the middle of nowhere, and see a goblin approaching you.")
    print("Panickedly looking around you identify three items laying on the ground.")
    print("A bow, sword, and staff(you sense something mystical about the staff.)")
    print("Instictively, you grab the...\n")
    choice = input("(Sword, Bow, or Staff) You Choose:" )
    choice = choice.lower()
    class_choice(choice)
    

sleep_count = 0 #keep running count of how many times they've sleep, note: user-interface will only show option to sleep after facing final boss. 
    while sleep_count < 4 : #While count is less than 3, continue
        sleep_count + 1
        if sleep_count == 0 :
            level_one = 'Granted' #Sets permission granted for this skill, allows it to be seen in user_interface. Use if statements
            print("You had a nice rest")
            break
            #Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
        elif sleep_count == 1 :
            level_two = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 2 :
            level_three = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 3: 
            level_four = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 4 :
            level_five = 'Granted'
            print("You had a nice rest")
            break
        else :
            print("You can no longer sleep.")
            print("error, check sleep wizard function.")

def update_permissions 
    #
lives = 3


#Knight Abilities 

slash_knight = {'pp':15, 'damage':20}
lunge_knight = {'pp':10, 'damage':25}
ironguardian_knight = {'pp':2, 'damage':20}
pivotdash_knight = {'pp':10, 'damage':35}
true_edge_knight = {'pp':1, 'damage':90}

#ARCHER ABILITIES 
arrow_archer = {'pp':15, 'damage':20}
precisionhit_archer = {'pp':10, 'damage':25}
focusbreath_archer = {'pp':2, 'heal':25}
acidarrow_pp = {'pp':10, 'damage':35}
stormarrow_archer = {'pp':1, 'damage':90}

#WIZARD ABILITIES PP

fireblast_wizard = {'pp':10, 'damage':25}
lightningstrike_wizard = {'pp':10, 'damage':35}
heal_wizard = {'pp':2, 'heal':40}
element_wave_wizard = {'pp':10, 'damage':45}
eruption_seal_wizard = {'pp':1, 'damage':90}


def attack_wizard(attack):
    if attack == 'fireblast':
        
    elif attack == 'lightningstrike_wizard'
    
    elif attack == 'heal'
    
    elif attack == 'element_wave'
    
    elif attack == 'eruption_seal'
    
def attack_knight
    if attack == ''

def attack_archer

    
    user_stats['armor'] > 0 :
                user_stats['armor'] - goblin_stats['attack']
                if user_stats['armor'] <= 0 :
                    user_stats['health'] + user_stats['armor']
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
            elif user_stats['health'] > 0 :
                user_stats['health'] - goblin_stats['attack'] 
                if user_stats['health'] <= 0
                    lives = lives - 1
                    print("You lost a life. Restarting from nearest checkpoint.")
                elif: user_stats['health'] > 0 :
                    print("You took some damage, but survived.")
                    print('Health:' user_stats['health'])
                    print('Armor:' user_stats['armor'])
    if 
    user_stats - 

def attack_archer

def attack_wizard
    
    
    knight_general_list = []
    knight_option_attack = input("Choose a move")
    knight_option_attack = knight_option_attack.lower()
    if knight_option_attack == 'slash':
        knight_general_list = slash_knight (slash_pp)
        slash_pp = knight_general_list[0]
        slash_damage = knight_general_list[1]
    elif knight_option_attack == 'lunge':
        knight_general_list = lunge_knight (lunge_pp)
        lunge_pp = knight_general_list[0]
        lunge_damage = knight_general_list[1]
    elif knight_option_attack == 'iron guardian' :
        knight_general_list = ironguardian_knight (ironguardian_pp)
        ironguardian_pp = knight_general_list[0]
        ironguardian_damage = knight_general_list[1]
    elif knight_option_attack == 'pivot dash':
        knight_general_list = pivotdash_knight (pivotdash_pp)
        pivotdash_pp = knight_general_list[0]
        pivotdash_damage = knight_general_list[1]
    elif knight_option_attack =='true edge' :
        knight_general_list = true_edge_knight(true_edge_pp)
        true_edge_pp = knight_general_list[0]
        true_edge_damage = knight_general_list[1]
    else :
        print("Error, knight abilities.")
    
#Takes spell, outputs damage and pp. Use this for user_interface.
def archer_attack(): #IMPLEMENT IF STATEMENTS RIGHT AFTER IF'S FOR PERMISSION
archer_general_list = []
archer_option_attack = input("Choose a move")
archer_optioni_attack = archer_option_attack.lower()
if archer_option_attack == 'arrow':
    archer_general_list = arrow_archer (arrow_pp)
    arrow_pp = archer_general_list[0]
    arrow_damage = archer_general_list[1]
elif archer_option_attack =='precision hit' :
    archer_general_list = precisionhit_archer (precisionhit_pp)
    precisionhit_pp = archer_general_list[0]
    precisionhit_pp = archer_general_list[1]
elif archer_option_attack == 'focus breathing' :
    archer_general_list = focusbreath_archer (focusbreath_pp)
    focusbreath_pp = archer_general_list[0]
    focusbreath_damage = archer_general_list[1]
elif archer_option_attack =='acid arrow' :
    archer_general_list = acidarrow_archer (acidarrow_pp)
    acidarrow_pp = archer_general_list[0]
    acidarrow_damage = archer_general_list[1]
elif archer_option_attack == 'storm arrow' :
    archer_general_list = stormarrow_archer (stormarrow_pp)
    stormarrow_pp = archer_general_list[0]
    stormarrow_damage = archer_general_list[1]
else :
    print("Error, Archer abilities.")

    
def wizard_attack ():
#Takes spell, outputs damage and pp. Use this for user_interface.
wizard_general_list = []
wizard_option_attack = input("Choose a spell.")
wizard_option_attack = wizard_option_attack.lower()
if wizard_option_attack == 'fireblast' :
    wizard_general_list = fireblast_wizard(fireblast_pp)
    fireblast_pp = wizard_general_list[0]
    fireblast_damage = wizard_general_list[1]
elif wizard_option_attack == 'lightning strike' :
    wizard_general_list = lightningstrike_wizard(lightningstrike_pp)
    lightningstrike_pp = wizard_general_list[0]
    lightningstrike_damage = wizard_general_list[1]
elif wizard_option_attack == 'heal':
    wizard_general_list = heal_wizard(heal_pp)
    heal_pp = wizard_general_list[0]
    heal_heal = wizard_general_list[1]
elif wizard_option_attack == 'element wave':
    wizard_general_list = element_wave_wizard(element_wave_pp)
    element_wave_pp = wizard_general_list[0]
    element_wave_damage = wizard_general_list[1]
elif wizard_option_attack == 'eruption seal':
    wizard_general_list = eruption_seal_wizard(eruption_seal_pp)
    eruption_seal_pp = wizard_general_list[0]
    eruption_seal_damage = wizard_general_list[1]
    

def dodge(CharacterType): #DODGE
random.randint(0,100)
if user_stats['speed'] >random.randint(0,100):
    (CharacterType)[5]=0
if user_status['speed'] <random.randit(0,100):
    continue
    
#knight_stats = {'CharacterType':'Knight','health':75,'armor':70,'speed':35,'attack':20}
#archer_stats = {'CharacterType': 'Archer','health':70,'armor':50,'speed':55,'attack':35}
#wizard_stats = {'CharacterType':'Wizard','health':65,'armor':50,'speed':25,'attck':45}
#goblin_stats = {'CharacterType':'Goblin','health':45,'armor':10,'speed':35,'attack':25}
#darkelf_stats = {'CharacterType':'Darkelves','health':55,'armor':25,'speed':40,'attack':35}
#vampire_stats={'CharacterType':'Vampire','health':70,'armor':30,'speed':40,'attack':35}
#werewolf_stats={'CharacterType':'Werewolf','health':80,'armor':55,'speed':50,'attack':55}
#dragon_stats={'CharacterType':'Dragon','health':100,'armor':100,'speed':100,'attack':100}

while True:
    print("You have encountered a goblin!")
# battle_interface
    battle_decision = input("You can 'run', 'attack', or check your 'inventory'. Please type your choice.")
    if battle_decision = 'run' :  #If user decides to run...
        random = random.randint(0,100)
        if user_stats[4] >= random:
            print("You successfully escaped! Fleeing from the woods you see the outlying of a town on the horizen!")
            village_welcome() #Transition to Village1
        elif user_status[4] < random.randit(0,100):
            print("You failed to escape.")
            if user_stats['armor'] > 0 :
                user_stats['armor'] - goblin_stats['attack']
                if user_stats['armor'] <= 0 :
                    user_stats['health'] + user_stats['armor']
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
            elif user_stats['health'] > 0 :
                user_stats['health'] - goblin_stats['attack'] 
                if user_stats['health'] <= 0
                    lives = lives - 1
                    print("You lost a life. Restarting from nearest checkpoint.")
                elif: user_stats['health'] > 0 :
                    print("You took some damage, but survived.")
                    print('Health:' user_stats['health'])
                    print('Armor:' user_stats['armor'])
                else:
                    print("Error.")
            else : 
                print("How are you even walking!?! You're dead!!")
                print('Health:' user_stats['health'])
                print('Armor:' user_stats['armor'])
        else: 
            print("Error")
    elif battle_decision = 'attack': #If user decides to attack
        
    elif battle_decision = 'inventory': #If user decides to prepare
        for line in user_invetory.items():
            print(line)
        user_choice_useitem = input("Which of your  like to use one of your items?")
        user_choice_useitem.lower
        if user_choice_useitem == ("
        
        
    else :
        print("Please choose one of the available choices.")
        
#Call next function(class_selection)


shop_inventory1 = {'health potion'= health_potion_small(),'shield'=shield_small()}
shop_inventory2 = {'health potion'= health_potion_medium(),'shield'=shield_medium()}
shop_inventory3 = {'health potion'= health_potion_large(), 'shield'=shield_large()}
#Carson will deal with those
user_stats['health']
user_stats['armor']
user_inventory={}
health_potions={'small': 20, 'medium': 50, 'large': 100}
armor={'small':20, 'medium':50, 'large':100}

#WILL BE BREAKING UP FOR EACH NIGHT AT VILLAGE.

            
def sleep_unlockskills_wizard (user_option): #character dream function
    sleep_count = 0 #keep running count of how many times they've sleep, note: user-interface will only show option to sleep after facing final boss. 
    while sleep_count < 4 : #While count is less than 3, continue
        sleep_count + 1
        if sleep_count == 0 :
            fireblast_wizard_permission = 'Granted' #Sets permission granted for this skill, allows it to be seen in user_interface. Use if statements
            print("You had a nice rest")
            break
            #Call User_interface(sleep_count, slash_knight_permission), MAKE SURE YOU USE BOTH AS ARGUMENTS!
        elif sleep_count == 1 :
            lightningstrike_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 2 :
            heal_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 3: 
            element_wave_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        elif sleep_count == 4 :
            eruption_seal_wizard_permission = 'Granted'
            print("You had a nice rest")
            break
        else :
            print("You can no longer sleep.")
            print("error, check sleep wizard function.")



#User_Interface_SleepOption

if user_option == 'sleep': #This will be used in the user interface, if the user types sleep, 
    if user_stats['CharacterType'] == 'Knight':
        sleep_unlockskills_knight()
        sleep_restore_knightpp()
    elif user_stats['CharacterType'] == 'Archer':
        sleep_unlockskills_archer()
        sleep_restore_archerpp()
    elif user_stats['CharacterType'] == 'Wizard':
        sleep_unlockskills_wizard()
        sleep_restore_wizardpp()
    else:
        print("Error, check sleep test.")
else :
    print("Code into overall for user_interface.")
    #Rerun user_interface



print('Proudly coded by Carson Baxter and Yang Zhang')
print('Supported by Angela, Loki and Issak')
print('Special thanks to people that tried to break our code')
print('Special thanks to Mr. Baxter and Ms. Frederickson!')
print('Special thanks to Mr. Zhang and Ms Huang')
# Out:
#   File "<tokenize>", line 209
#     elif user_stats['health'] > 0 :
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#TESTER FOR USERNAME

# %%
import random
import time

def wait(duration):
    time.sleep(duration)
    
def journey_start():
    print("Welcome,", username + '.')
    
def character_backstory(username):
    username_local = username
    user_skip = input("Would you like to skip the backstory? 'Yes' or 'No'.")
    user_skip.lower()
    if user_skip == 'yes':
        journey_start()
    elif user_skip == 'no' :
        wait(2)
        print("There was once a great person who fought for the freedom of their village!, their name?")
        wait(2)
        print(username_local)
        wait(2)
        print(username_local, "was a war veteran who fought for his country...")
        wait(2)
        print("To protect his village he had to fight many monsters...")
        wait(2)
        print("In order to defend his vilage", username_local, "faced the monster boss, kragula...")
        wait(3)
        print(username_local, "failed to win the fight and is presumed dead, his village, enslaved...")
        wait(2)
        print(username_local, "wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.")
        wait(3)
        journey_start()
    else :
        print("You must type 'Yes' or 'No'.")
        character_backstory(username_local)


def display_user_stats(user_stats):
    for keys, values in user_stats.items() :
        print(keys +":", values)

user_stats= {}
user_inventory = {}
class_variable = ''
sleep_count = 0
knight_stats = {'CharacterType':'Knight','health':75,'armor':70,'speed':35,'attack':20}
archer_stats = {'CharacterType': 'Archer','health':70,'armor':50,'speed':55,'attack':35}
wizard_stats = {'CharacterType':'Wizard','health':65,'armor':50,'speed':25,'attck':45}
goblin_stats = {'CharacterType':'Goblin','health':45,'armor':10,'speed':35,'attack':25}
darkelf_stats = {'CharacterType':'Darkelves','health':55,'armor':25,'speed':40,'attack':35}
vampire_stats={'CharacterType':'Vampire','health':70,'armor':30,'speed':40,'attack':35}
werewolf_stats={'CharacterType':'Werewolf','health':80,'armor':55,'speed':50,'attack':55}
dragon_stats={'CharacterType':'Dragon','health':100,'armor':100,'speed':100,'attack':100}


namecheck = []
filename='Random_Name_Data.txt'
with open (filename,'r') as namelist:
    for name in namelist.readlines():
        namecheck.append(name) 
while True:
    user_input = input("Please enter a username, or type 'random' to receive a random name: ")
    user_input = user_input.lower()
    if user_input == 'random' :
        username = random.choice(namecheck)
        print("Your randomly generated username is %s." % (username))
        confirm_input = input("Please type 'yes' or 'no' to confirm your username.")
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        elif confirm_input == 'no' : 
            print("Restarting...\n")
            wait(2)
            #Need to put in restart
        else : 
            print("Please try again. Restarting...")
            wait(2)
            #Need to put in restart
    else:
        username = user_input
        print("Your username is now:", username)
        confirm_input = input("Please type 'yes' or 'no' to confirm your username.")
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        elif confirm_input == 'no' : 
            print("Restarting...\n")
            wait(2)
            #Need to put in restart
        else :
            print("Please try again. Restarting...")
            wait(2)
            #Need to put in restart 
            
journey_confirmation=input("Would you like to start your journey? Please enter 'yes' or 'no' to confirm.")
journey_confirmation = journey_confirmation.lower()
if journey_confirmation=="yes":
    print("\n\nYou wake up in the middle of nowhere, and see a goblin approaching you.")
    print("Panickedly looking around you identify three items laying on the ground.")
    print("A bow, sword, and staff(you sense something mystical about the staff.)")
    print("Instictively, you grab the...\n")
    choice = input("(Sword, Bow, or Staff) You Choose:" )
    choice = choice.lower()
    if choice =='sword':
        class_variable = 'knight'
        user_stats = knight_stats
        print("Congratulations, you are now a knight!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    elif choice=='bow':
        class_variable = 'archer'
        user_stats = archer_stats
        print("Congratulations, you are now an archer!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    elif choice=='staff':
        class_variable = 'wizard'
        user_stats = wizard_stats
        print("Congratulations, you are now a wizard!")
        print("Here are your stats!")
        display_user_stats(user_stats)
        transition_class_firstbattle()
    else :
        print("Restarting journey...")
        journey_start()
elif journey_confirmation == 'no':
    print("Restarting journey...")
    journey_start()
    

else:
    print("You must type in either, 'yes' or 'no'.")
    print("Restarting journey...")
    journey_start()
#Note: You should have something within the staff, bow,
#and sword choices for restarting the journey potion in case they don't like their class.

# %%
import random
import time

def wait(duration):
    time.sleep(duration)

def character_backstory(username):
    user_skip = input("Would you like to skip the backstory? 'Yes' or 'No'.")
    user_skip.lower()
    if user_skip == 'yes':
        journey_start()
    elif user_skip == 'no' :
        wait(3)
        print("There was once a great person who fought for the freedom of their village!, their name?")
        wait(3)
        print(username)
        wait(2)
        print(username, "was a war veteran who fought for his country...")
        wait(3)
        print("To protect his village he had to fight many monsters...")
        wait(3)
        print("In order to defend his vilage", username, "faced the monster boss, kragula...")
        wait(4)
        print(username, "fails to win the fight and is presumed dead, his village, enslaved...")
        wait(3)
        print(username, "wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.")
        wait(4)
        journey_start()
    else :
        print("You must type 'Yes' or 'No'.")
        character_backstory(username)
    


namecheck = []
filename='Random_Name_Data.txt'
with open (filename,'r') as namelist:
    for name in namelist.readlines():
        namecheck.append(name) 
while True:
    user_input = input("Please enter a username, or type 'random' to receive a random name: ")
    if user_input == 'random' :
        username = random.choice(namecheck)
        print("Your randomly generated username is %s." % (username))
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_input.lower()
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else : 
            print("Please try again. Restarting...")
            wait(2)
    else:
        username = user_input
        print("Your username is now:", username)
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_input.lower()
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else :
            print("Please try again. Restarting...")
            wait(2)


knight_stats = {'CharacterType':'Knight','health':75,'armor':70,'speed':35,'attack':20}
archer_stats = {'CharacterType': 'Archer','health':70,'armor':50,'speed':55,'attack':35}
wizard_stats = {'CharacterType':'Wizard','health':65,'armor':50,'speed':25,'attck':45}
goblin_stats = {'CharacterType':'Goblin','health':45,'armor':10,'speed':35,'attack':25}
darkelf_stats = {'CharacterType':'Darkelves','health':55,'armor':25,'speed':40,'attack':35}
vampire_stats={'CharacterType':'Vampire','health':70,'armor':30,'speed':40,'attack':35}
werewolf_stats={'CharacterType':'Werewolf','health':80,'armor':55,'speed':50,'attack':55}
dragon_stats={'CharacterType':'Dragon','health':100,'armor':100,'speed':100,'attack':100}
user_inventory = {}
user_stats= {}
class_variable = ''
sleep_count = 0

def journey_start():
    print("Welcome,", username + '.')
    journey_confirmation_class_assignment()

def journey_confirmation_class_assignment():
    print("You are now entering battle phase!")
    journey_confirmation=input("Would you like to start your journey? Please enter 'yes' or 'no' to confirm.")
    journey_confirmation = journey_confirmation.lower()
    if journey_confirmation=="yes":
        print("\n\nYou wake up in the middle of nowhere, and see a goblin approaching you.")
        print("Panickedly looking around you identify three items laying on the ground.")
        print("A bow, sword, and staff(you sense something mystical about the staff.)")
        print("Instictively, you grab the...\n")
        choice = input("(Sword, Bow, or Staff) You Choose:" )
        if choice =='sword':
            class_variable = 'knight'
            global user_stats
            user_stats = user_stats.items() + knight_stats.items()
            print("Congratulations, you are now a knight!")
            print("Here are your stats!")
            for keys, values in user_stats.items() :
                print(keys +":", values)
            transition_class_battle()
        elif choice=='bow':
            class_variable = 'archer'
            global user_stats
            user_stats = user_stats.items() + archer_stats.items()
            print("Congratulations, you are now an archer!")
            print("Here are your stats!")
            for keys, values in user_stats.items() :
                print(keys +":", values)
            transition_class_battle()
        elif choice=='staff':
            class_variable = 'wizard'
            global user_stats
            user_stats = user_stats.items() + wizard_stats.items()
            print("Congratulations, you are now a wizard!")
            print("Here are your stats!")
            for keys, values in user_stats.items() :
                print(keys +":", values)
            transition_class_battle()
        else :
            print("Restarting journey...")
            journey_confirmation_class_assignment()
    elif journey_confirmation == 'no' :
        print("Restarting journey...")
        journey_confirmation_class_assignment()
    
        
slash_knight = {'pp':15, 'damage':20}
lunge_knight = {'pp':10, 'damage':25}
ironguardian_knight = {'pp':2, 'damage':20}
pivotdash_knight = {'pp':10, 'damage':35}
true_edge_knight = {'pp':1, 'damage':90}

arrow_archer = {'pp':15, 'damage':20}
precisionhit_archer = {'pp':10, 'damage':25}
focusbreath_archer = {'pp':2, 'heal':25}
acidarrow_pp = {'pp':10, 'damage':35}
stormarrow_archer = {'pp':1, 'damage':90}
        
fireblast_wizard = {'pp':10, 'damage':25}
lightningstrike_wizard = {'pp':10, 'damage':35}
heal_wizard = {'pp':2, 'heal':40}
element_wave_wizard = {'pp':10, 'damage':45}
eruption_seal_wizard = {'pp':1, 'damage':90}


def transition_class_battle():
    print("You are now entering battle phase!")
    battle_decision = input("You can 'run' or 'attack'. Please type your choice.")
    battle_decision=battle_decision.lower()
try : 
    if battle_decision == 'run' :  #If user decides to run...
        random = random.randint(0,100)
        if user_stats['speed'] >= random:
            print("You successfully escaped! Fleeing from the woods you see the outlying of a town on the horizen!")
            village_welcome() #Transition to Village1
        elif user_status[4] < random.randit(0,100):
            print("You failed to escape.")
            if user_stats['armor'] > 0 :
                user_stats['armor'] = user_stats['armor'] - goblin_stats['attack']
                if user_stats['armor'] <= 0 :
                    user_stats['health'] + user_stats['armor']
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
                elif user_stats['health'] > 0 :
                    user_stats['health'] = user_stats['health'] - goblin_stats['attack'] 
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
                elif user_stats['health'] > 0 :
                    print("You took some damage, but survived.")
                    print('Health:', user_stats['health'])
                    print('Armor:', user_stats['armor'])
                else:
                    print("Error.")
            else : 
                print("How are you even walking!?! You're dead!!")
                print('Health:', user_stats['health'])
                print('Armor:', user_stats['armor'])
        else: 
            print("Error")
    elif battle_decision == 'attack':
        while user_stats['health'] > 0 or goblin_stats['health'] > 0 :
            if user_stats['CharacterType']=='Knight':
                move=input("You can attack with 'slash'. Type 'slash' to attack the goblin.")
                while move != 'slash':
                    move=input('Please enter a move')
                    slash.knight['pp']=slash.knight['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - slash.knight['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
            elif user_stats['CharacterType']=='Archer':
                move=input("You can attack with 'arrow'. Type 'arrow' to attack the goblin.")
                while move != 'arrow':
                    move=input('Please enter a move')
                    arrow.archer['pp']=arrow.archer['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - arrow.archer['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
            elif user_stats['CharacterType']=='Wizard':
                move=input("You can attack with 'fireblast'. Type 'fireblast' to attack the goblin.")
                while move != 'fireblast':
                    move=input('Please enter a move')
                    fireblast.wizard['pp']=fireblast.wizard['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - fireblast.wizard['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
                    user_stats['health'] = user_stats['health'] - goblin_stats['attack']
                    print('The goblin attacked you, you have ', user_stats['health'],'left')
            else:
                print("Error.")
    else:
        print("error.")
except: 
    print("You ran away and made it to a nearby village where you found safety!")
    
def sleep_restore_wizardpp():
    fireblast_pp = 10
    lightningstrike_pp = 10
    heal_pp = 2
    element_wave_pp = 10
    eruption_seal_wizard = 1
    return fireblast_pp, lightningstrike_pp, heal_pp, element_wave_pp, eruption_seal_wizard

def sleep_restore_archerpp():
    arrow_pp = 15
    precisionhit_pp = 10
    focusbreath_pp = 2
    acidarrow_pp = 10
    stormarrow_pp = 1
    return arrow_pp, precisionhit_pp, focus_breath_pp, acidarrow_pp, stormarrow_pp

def sleep_restore_knightpp():
    slash_pp = 15
    lunge_pp = 10
    ironguardian_pp = 2
    pivotdash_pp = 10
    true_edge_pp = 1
    return slash_pp, lunge_pp, ironguardian_pp, pivotdash_pp, true_edge_pp

def end():    
    print('Proudly coded by Carson Baxter and Yang Zhang')
    print('Supported by Angela, Loki and Issak')
    print('Special thanks to people that tried to break our code')
    print('Special thanks to Mr. Baxter and Ms. Frederickson!')
    print('Special thanks to Mr. Zhang and Ms Huang')

town_names = ['Briar Glen', 'Alcombey', 'Keld']
print("Welcome to", town_names[1] + "!")
print("Suddenly, you feel exhausted. Moving slowly you make your way to a cheap inn to spend the night.")
sleep_count = 0
sleep_count = sleep_count + 5
print("Sleeping...")

if user_stats['CharacterType'] == 'knight' :
    knight_ability_list = []
    knight_ability_list = sleep_restore_archerpp()
    slash_pp = knight_ability_list[0]
    lunge_pp = knight_ability_list[1]
    ironguardian_pp = knight_ability_list[2]
    pivotdash_pp = knight_ability_list[3]
    true_edge_pp = knight_ability_list[4]
    
elif user_stats['CharacterType'] == 'archer':
    archer_ability_list = []
    archer_ability_list = sleep_restore_archerpp()
    arrow_pp = archer_ability_list[0]
    precisionhit_pp = archer_ability_list[1]
    focusbreath_pp = archer_ability_list[2]
    acidarrow_pp = archer_ability_list[3]
    stormarrow_pp = archer_ability_list[4]
    
elif user_stats['CharacterType'] == 'wizard' :
    wizard_ability_list = []
    wizard_ability_list = sleep_restore_wizardpp()
    fireblast_pp = wizard_ability_list[0]
    lightningstrike_pp = wizard_ability_list[1]
    heal_pp = wizard_ability_list[2]
    element_wave_pp = wizard_ability_list[3]
    eruption_seal_wizard = wizard_ability_list[4]
wait(4)
print("All your pp(power points) and health has been restored.")
print("In the morning you are awake and refreshed! You eat breakfast and make your way outside.")
print("Where would you like to go in the village? You may visit the, 'Shop', 'Inn', or 'leave'. ")
while True:
    user_village_choice = input("Type 'Shop' for shop, 'Inn' for Inn, or 'leave' for leave.")
    user_village_choicel = user_village_choice.lower()
    if user_village_choice == 'shop' or 'inn' or 'leave':
        print("Suddenly, you are stopped by a little girl crying to you. You pick her up, and find that she is an orphan")
        print("You take her in as your own and give up your adventuring days.")
        end()
    else :
        print("You must choose one of the choices.")
# Out:
#   File "<ipython-input-3-654cbd9f24ef>", line 109
#     print("Here are your stats!")
#            ^
# SyntaxError: name 'user_stats' is used prior to global declaration

# %%
import random
import time

def wait(duration):
    time.sleep(duration)
    
def journey_start():
    print("Welcome,", username + '.')
    journey_confirmation_class_assignment()

def character_backstory(username):
    user_skip = input("Would you like to skip the backstory? 'Yes' or 'No'.")
    user_skip.lower()
    if user_skip == 'yes':
        journey_start()
    elif user_skip == 'no' :
        wait(3)
        print("There was once a great person who fought for the freedom of their village!, their name?")
        wait(3)
        print(username)
        wait(2)
        print(username, "was a war veteran who fought for his country...")
        wait(3)
        print("To protect his village he had to fight many monsters...")
        wait(3)
        print("In order to defend his vilage", username, "faced the monster boss, kragula...")
        wait(4)
        print(username, "fails to win the fight and is presumed dead, his village, enslaved...")
        wait(3)
        print(username, "wakes up with no memory of who he was and soon realizes in surprise, that he his skills from muscle memory clearly embedded in him from years of experience.")
        wait(4)
        journey_start()
    else :
        print("You must type 'Yes' or 'No'.")
        character_backstory(username)
    
def display_user_stats(user_stats):
    for keys, values in user_stats.items() :
        print(keys +":", values)
#This will go first, as the other functions wont be called, 
#however, they must be before this so that it can be called.
namecheck = []
filename='Random_Name_Data.txt'
with open (filename,'r') as namelist:
    for name in namelist.readlines():
        namecheck.append(name) 
while True:
    user_input = input("Please enter a username, or type 'random' to receive a random name: ")
    if user_input == 'random' :
        username = random.choice(namecheck)
        print("Your randomly generated username is %s." % (username))
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_input.lower()
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else : 
            print("Please try again. Restarting...")
            wait(2)
    else:
        username = user_input
        print("Your username is now:", username)
        confirm_input = input("Please type 'yes' to confirm your username. Type anything to change your username.")
        confirm_input.lower()
        if confirm_input == 'yes' : 
            print("Congratulations! You are now %s!" % (username))
            character_backstory(username)
            break
        else :
            print("Please try again. Restarting...")
            wait(2)

user_inventory = {}
user_stats= {} #Will be assigned either knight, archer, or wizard stats. 
#Static stats. 
class_variable = ''
sleep_count = 0
knight_stats = {'CharacterType':'Knight','health':75,'armor':70,'speed':35,'attack':20}
archer_stats = {'CharacterType': 'Archer','health':70,'armor':50,'speed':55,'attack':35}
wizard_stats = {'CharacterType':'Wizard','health':65,'armor':50,'speed':25,'attck':45}
goblin_stats = {'CharacterType':'Goblin','health':45,'armor':10,'speed':35,'attack':25}
darkelf_stats = {'CharacterType':'Darkelves','health':55,'armor':25,'speed':40,'attack':35}
vampire_stats={'CharacterType':'Vampire','health':70,'armor':30,'speed':40,'attack':35}
werewolf_stats={'CharacterType':'Werewolf','health':80,'armor':55,'speed':50,'attack':55}
dragon_stats={'CharacterType':'Dragon','health':100,'armor':100,'speed':100,'attack':100}




def journey_confirmation_class_assignment():
    user_confirmation=input("Would you like to start your journey? Please enter 'yes' or 'no' to confirm.")
    user_confirmation = user_confirmation.lower()
    if user_confirmation=="yes":
        print("\n\nYou wake up in the middle of nowhere, and see a goblin approaching you.")
        print("Panickedly looking around you identify three items laying on the ground.")
        print("A bow, sword, and staff(you sense something mystical about the staff.)")
        print("Instictively, you grab the...\n")
        choice = input("(Sword, Bow, or Staff) You Choose:" )
        if choice =='sword':
            class_variable = 'knight'
            user_stats = knight_stats 
            print("Congratulations, you are now a knight!")
            print("Here are your stats!")
            display_user_stats(user_stats)
            transition_class_battle()
        elif choice=='bow':
            class_variable = 'archer'
            user_stats = archer_stats
            print("Congratulations, you are now an archer!")
            print("Here are your stats!")
            display_user_stats(user_stats)
            transition_class_battle()
        elif choice=='staff':
            class_variable = 'wizard'
            user_stats = wizard_stats
            print("Congratulations, you are now a wizard!")
            print("Here are your stats!")
            display_user_stats(user_stats)
            transition_class_battle()
        else :
            print("Restarting journey...")
            journey_confirmation_class_assignment()
    elif journey_confirmation == 'no' :
        print("Restarting journey...")
        journey_confirmation_class_assignment()
    
slash_knight = {'pp':15, 'damage':20}
lunge_knight = {'pp':10, 'damage':25}
ironguardian_knight = {'pp':2, 'damage':20}
pivotdash_knight = {'pp':10, 'damage':35}
true_edge_knight = {'pp':1, 'damage':90}

arrow_archer = {'pp':15, 'damage':20}
precisionhit_archer = {'pp':10, 'damage':25}
focusbreath_archer = {'pp':2, 'heal':25}
acidarrow_pp = {'pp':10, 'damage':35}
stormarrow_archer = {'pp':1, 'damage':90}
        
fireblast_wizard = {'pp':10, 'damage':25}
lightningstrike_wizard = {'pp':10, 'damage':35}
heal_wizard = {'pp':2, 'heal':40}
element_wave_wizard = {'pp':10, 'damage':45}
eruption_seal_wizard = {'pp':1, 'damage':90}


def transition_class_battle():
    print("You are now entering battle phase!")
    battle_decision = input("You can 'run' or 'attack'. Please type your choice.")
    battle_decision=battle_decision.lower()
try : 
    if battle_decision == 'run' :  #If user decides to run...
        random = random.randint(0,100)
        if user_stats['speed'] >= random:
            print("You successfully escaped! Fleeing from the woods you see the outlying of a town on the horizen!")
            village_welcome() #Transition to Village1
        elif user_status[4] < random.randit(0,100):
            print("You failed to escape.")
            if user_stats['armor'] > 0 :
                user_stats['armor'] = user_stats['armor'] - goblin_stats['attack']
                if user_stats['armor'] <= 0 :
                    user_stats['health'] + user_stats['armor']
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
                elif user_stats['health'] > 0 :
                    user_stats['health'] = user_stats['health'] - goblin_stats['attack'] 
                    if user_stats['health'] <= 0:
                        lives = lives - 1
                        print("You lost a life. Restarting from nearest checkpoint.")
                        journey_start()
                elif user_stats['health'] > 0 :
                    print("You took some damage, but survived.")
                    print('Health:', user_stats['health'])
                    print('Armor:', user_stats['armor'])
                else:
                    print("Error.")
            else : 
                print("How are you even walking!?! You're dead!!")
                print('Health:', user_stats['health'])
                print('Armor:', user_stats['armor'])
        else: 
            print("Error")
    elif battle_decision == 'attack':
        while user_stats['health'] > 0 or goblin_stats['health'] > 0 :
            if user_stats['CharacterType']=='Knight':
                move=input("You can attack with 'slash'. Type 'slash' to attack the goblin.")
                while move != 'slash':
                    move=input('Please enter a move')
                    slash.knight['pp']=slash.knight['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - slash.knight['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
            elif user_stats['CharacterType']=='Archer':
                move=input("You can attack with 'arrow'. Type 'arrow' to attack the goblin.")
                while move != 'arrow':
                    move=input('Please enter a move')
                    arrow.archer['pp']=arrow.archer['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - arrow.archer['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
            elif user_stats['CharacterType']=='Wizard':
                move=input("You can attack with 'fireblast'. Type 'fireblast' to attack the goblin.")
                while move != 'fireblast':
                    move=input('Please enter a move')
                    fireblast.wizard['pp']=fireblast.wizard['pp'] - 1
                    goblin_stats['health']=goblin_stats['health'] - fireblast.wizard['damage']
                    print('You have reduced goblins health to', goblin_stats['health'])
                    user_stats['health'] = user_stats['health'] - goblin_stats['attack']
                    print('The goblin attacked you, you have ', user_stats['health'],'left')
            else:
                print("Error.")
    else:
        print("error.")
except: #Used as decoy.
    print("You stumbled and couldn't fight anymore, limping away, you make it to a nearby village where you found safety!")
    
def sleep_restore_wizardpp():
    fireblast_pp = 10
    lightningstrike_pp = 10
    heal_pp = 2
    element_wave_pp = 10
    eruption_seal_wizard = 1
    return fireblast_pp, lightningstrike_pp, heal_pp, element_wave_pp, eruption_seal_wizard

def sleep_restore_archerpp():
    arrow_pp = 15
    precisionhit_pp = 10
    focusbreath_pp = 2
    acidarrow_pp = 10
    stormarrow_pp = 1
    return arrow_pp, precisionhit_pp, focus_breath_pp, acidarrow_pp, stormarrow_pp

def sleep_restore_knightpp():
    slash_pp = 15
    lunge_pp = 10
    ironguardian_pp = 2
    pivotdash_pp = 10
    true_edge_pp = 1
    return slash_pp, lunge_pp, ironguardian_pp, pivotdash_pp, true_edge_pp

def end():    
    print('Proudly coded by Carson Baxter and Yang Zhang')
    print('Supported by Angela, Loki and Issak')
    print('Special thanks to people that tried to break our code')
    print('Special thanks to Mr. Baxter and Ms. Frederickson!')
    print('Special thanks to Mr. Zhang and Ms Huang')

town_names = ['Briar Glen', 'Alcombey', 'Keld']
print("Welcome to", town_names[1] + "!")
print("Suddenly, you feel exhausted. Moving slowly you make your way to a cheap inn to spend the night.")
sleep_count = 0
sleep_count = sleep_count + 5
print("Sleeping...")

if user_stats['CharacterType'] == 'knight' :
    knight_ability_list = []
    knight_ability_list = sleep_restore_archerpp()
    slash_pp = knight_ability_list[0]
    lunge_pp = knight_ability_list[1]
    ironguardian_pp = knight_ability_list[2]
    pivotdash_pp = knight_ability_list[3]
    true_edge_pp = knight_ability_list[4]
    
elif user_stats['CharacterType'] == 'archer':
    archer_ability_list = []
    archer_ability_list = sleep_restore_archerpp()
    arrow_pp = archer_ability_list[0]
    precisionhit_pp = archer_ability_list[1]
    focusbreath_pp = archer_ability_list[2]
    acidarrow_pp = archer_ability_list[3]
    stormarrow_pp = archer_ability_list[4]
    
elif user_stats['CharacterType'] == 'wizard' :
    wizard_ability_list = []
    wizard_ability_list = sleep_restore_wizardpp()
    fireblast_pp = wizard_ability_list[0]
    lightningstrike_pp = wizard_ability_list[1]
    heal_pp = wizard_ability_list[2]
    element_wave_pp = wizard_ability_list[3]
    eruption_seal_wizard = wizard_ability_list[4]
    

wait(4)
print("All your pp(power points) and health has been restored.")
print("In the morning you are awake and refreshed! You eat breakfast and make your way outside.")
print("Where would you like to go in the village? You may visit the, 'Shop', 'Inn', or 'leave'. ")
while True:
    user_village_choice = input("Type 'Shop' for shop, 'Inn' for Inn, or 'leave' for leave.")
    user_village_choicel = user_village_choice.lower()
    if user_village_choice == 'shop' or 'inn' or 'leave':
        print("Suddenly, you are stopped by a little girl crying to you. You pick her up, and find that she is an orphan")
        print("You take her in as your own and give up your adventuring days.")
        end()
    else :
        print("You must choose one of the choices.")

# %%
# Out:
# Please enter a username, or type 'random' to receive a random name: random
# Your username is now: random
# Please type 'yes' to confirm your username. Type anything to change your username.yes
# Please try again. Restarting...
# Please enter a username, or type 'random' to receive a random name: random
# Your username is now: random
# Please type 'yes' to confirm your username. Type anything to change your username.yes
# Congratulations! You are now random !
# Would you like to skip the backstory? 'Yes' or 'No'.no
# There was once a great person who fought for the freedom of their village!, their name?
# random
# random  was a war veteran who fought for his country...
# To protect his village he had to fight many monsters...
# In order to defend his vilage random  faced the monster boss, kragula...
# random  fails to win the fight and is presumed dead, his village, enslaved...
# ...

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'clock',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname',
#  'tzset']
